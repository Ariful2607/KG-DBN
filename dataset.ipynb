# %%
import pandas as pd
import random

def generate_synthetic_dataset(num_records):
    # Define a list of symptoms, and diseases
    symptoms = ["Enlarging root", 
                "Rotten rot", 
                "Blackened root", 
                "Spotted stem",
                "Rotten stem", 
                "Spotted leaves", 
                "Striped leaves", 
                "Withered leaves",
                "Reddened leaves", 
                "Drying leaves", 
                "Clumped leaves", 
                "Yellowing leaves",
                "Spotted panicle", 
                "Panicle forms spores", 
                "Rotten panicle", 
                "Drying panicle",
                "Shrinking panicles", 
                "Panicles produce fluid", 
                "Panicles falls out", 
                "Spotted sheath",
                "Striped sheath", 
                "Rotten sheath", 
                "Drying sheath", 
                "Decreased yields",
                "Plants collapsed easily", 
                "Plants grow curved", 
                "Plants grow stunted", 
                "Plants grow tall", 
                "Dwarf"]
    
    diseases = ["Bakanae", 
                "Bacterial Leaf Streak", 
                "Rice Blast", 
                "Brown Spot", 
                "Root rot", 
                "Stem rot",
                "Sheath rot",
                "Red Stripe Disease",
                "Kernel Smut", 
                "Bacterial Blight", 
                "Bacterial Pinacle Blight",
                "Sheath Blight", 
                "False Smut", 
                "Leaf Scald",
                "Rice Tungro", 
                "Rice Yellow Mottle",
                "Rice Grassy Stunt"]

    # Generate synthetic data for the dataset
    data = {
        "id": list(range(1, num_records + 1)),
        "symptoms": random.choices(symptoms, k=num_records),
        "disease": ["" for _ in range(num_records)],
    }

    # Assign specific diseases to sets of symptoms and pathogens/pests
    for i in range(num_records):
        if data["symptoms"][i] in ["Enlarging root"]:
            data["disease"][i] = "Bakanae"
        elif data["symptoms"][i] in ["Rotten rot"]:
            data["disease"][i] = "Root rot"
        elif data["symptoms"][i] in ["Blackened root"]:
            data["disease"][i] = "Root rot"
        elif data["symptoms"][i] in ["Spotted stem"]:
            data["disease"][i] = random.choice(["Bakanae", 
                                                "Brown Spot", 
                                                "Rice Blast", 
                                                "Stem rot"])
        elif data["symptoms"][i] in ["Rotten stem"]:
            data["disease"][i] = "Stem rot"
        elif data["symptoms"][i] in ["Spotted leaves"]:
            data["disease"][i] = random.choice(["Bacterial Leaf Streak", 
                                                "Brown Spot", 
                                                "Rice Blast", 
                                                "Red Stripe Disease", 
                                                "Bacterial blight", 
                                                "Sheath blight", 
                                                "Leaf scald"])
        elif data["symptoms"][i] in ["Striped leaves"]:
            data["disease"][i] = random.choice(["Bacterial Leaf Streak", 
                                                "Red Stripe Disease", 
                                                "Bacterial blight"])
            
        elif data["symptoms"][i] in ["Withered leaves"]:
            data["disease"][i] = "Rice Tungro"
        elif data["symptoms"][i] in ["Reddened leaves"]:
            data["disease"][i] = "Stem rot"
        elif data["symptoms"][i] in ["Drying leaves"]:
            data["disease"][i] = random.choice(["Bacterial Leaf Streak", 
                                                "Brown Spot", 
                                                "Rice Blast", 
                                                "Red Stripe Disease", 
                                                "Bacterial blight",  
                                                "Leaf scald"])
        elif data["symptoms"][i] in ["Clumped leaves"]:
            data["disease"][i] = "Rice Yellow Mottle"
        elif data["symptoms"][i] in ["Yellowing leaves"]:
            data["disease"][i] = random.choice(["bakanae",
                                                "Bacterial Leaf Streak", 
                                                "Brown Spot",
                                                "Bacterial blight", 
                                                "Rice Tungro", 
                                                "Rice Yellow Mottle",
                                                "Rice Grassy Stunt"])
            
        elif data["symptoms"][i] in ["Spotted panicle"]:
            data["disease"][i] = random.choice(["Brown Spot",
                                                "Rice Blast", 
                                                "Stem rot", 
                                                "Kernel Smut", 
                                                "Bacterial Pinacle Blight"])
        elif data["symptoms"][i] in ["Panicle forms spores"]:
            data["disease"][i] = "False smut"
        elif data["symptoms"][i] in ["Rotten panicle"]:
            data["disease"][i] = random.choice(["Kernel Smut",
                                                "Bacterial Pinacle Blight"])
        elif data["symptoms"][i] in ["Drying panicle"]:
            data["disease"][i] = random.choice(["Kernel Smut",
                                                "Bacterial Pinacle Blight"])
        elif data["symptoms"][i] in ["Shrinking panicles"]:
            data["disease"][i] = random.choice(["Sheath rot",
                                                "False smut"])
        elif data["symptoms"][i] in ["Panicles produce fluid"]:
            data["disease"][i] = "Bacterial Pinacle Blight"
        elif data["symptoms"][i] in ["Panicles falls out"]:
            data["disease"][i] = random.choice(["Stem rot",
                                                "Kernel Smut"])
        elif data["symptoms"][i] in ["Spotted sheath"]:
            data["disease"][i] = random.choice(["Sheath rot",
                                                "Red Stripe Disease",
                                                "Sheath blight"])
        elif data["symptoms"][i] in ["Striped sheath"]:
            data["disease"][i] = "Sheath blight"
        elif data["symptoms"][i] in ["Rotten sheath"]:
            data["disease"][i] = "Sheath rot"
        elif data["symptoms"][i] in ["Drying sheath"]:
            data["disease"][i] = random.choice(["Sheath rot",
                                                "Sheath blight"])
        elif data["symptoms"][i] in ["Decreased yields"]:
            data["disease"][i] = random.choice(["Kernel Smut", 
                                                "Bacterial blight", 
                                                "Bacterial Pinacle Blight", 
                                                "False smut", 
                                                "Leaf scald", 
                                                "Rice Tungro", 
                                                "Rice Grassy Stunt"])
        elif data["symptoms"][i] in ["Plants collapsed easily"]:
            data["disease"][i] = "Root rot"
        elif data["symptoms"][i] in ["Plants grow curved"]:
            data["disease"][i] = random.choice(["Bakanae",
                                                "Rice Blast", 
                                                "Rice Tungro", 
                                                "Rice Yellow Mottle", 
                                                "Rice Grassy Stunt"])
        elif data["symptoms"][i] in ["Plants grow stunted"]:
            data["disease"][i] = random.choice(["Bacterial Leaf Streak", 
                                                "Root rot", 
                                                "Sheath rot", 
                                                "Red Stripe Disease", 
                                                "Sheath blight", 
                                                "Leaf scald",
                                                "Rice Tungro",
                                                "Rice Yellow Mottle"])
        elif data["symptoms"][i] in ["Plants grow tall"]:
            data["disease"][i] = "Bakanae"
        elif data["symptoms"][i] in ["Dwarf"]:
            data["disease"][i] = random.choice(["Rice Yellow Mottle",
                                                "Rice Grassy Stunt"])
            
    # Create the DataFrame from the data dictionary
    df = pd.DataFrame(data)

    return df

# Generate a synthetic dataset with 100 records
dataset = generate_synthetic_dataset(2671994)
print(dataset)

# %%
# Save the full dataset to a CSV file
dataset.to_csv("full_dataset.csv", index=False)

# %%
import pandas as pd
import random
from datetime import datetime, timedelta, time

def generate_synthetic_dataset(num_records):
    # Define a list of symptoms, and diseases
    symptoms = ["Enlarging root", 
                "Rotten rot", 
                "Blackened root", 
                "Spotted stem",
                "Rotten stem", 
                "Spotted leaves", 
                "Striped leaves", 
                "Withered leaves",
                "Reddened leaves", 
                "Drying leaves", 
                "Clumped leaves", 
                "Yellowing leaves",
                "Spotted panicle", 
                "Panicle forms spores", 
                "Rotten panicle", 
                "Drying panicle",
                "Shrinking panicles", 
                "Panicles produce fluid", 
                "Panicles falls out", 
                "Spotted sheath",
                "Striped sheath", 
                "Rotten sheath", 
                "Drying sheath", 
                "Decreased yields",
                "Plants collapsed easily", 
                "Plants grow curved", 
                "Plants grow stunted", 
                "Plants grow tall", 
                "Dwarf"]
    
    diseases = ["Bakanae", 
                "Bacterial Leaf Streak", 
                "Rice Blast", 
                "Brown Spot", 
                "Root rot", 
                "Stem rot",
                "Sheath rot",
                "Red Stripe Disease",
                "Kernel Smut", 
                "Bacterial Blight", 
                "Bacterial Pinacle Blight",
                "Sheath Blight", 
                "False Smut", 
                "Leaf Scald",
                "Rice Tungro", 
                "Rice Yellow Mottle",
                "Rice Grassy Stunt"]

    # Define a list of possible temperature and humidity ranges
    temperature_ranges = [(20, 30), (25, 35), (22, 28), (18, 25), (30, 35)]
    humidity_ranges = [(40, 60), (50, 70), (55, 75), (60, 80), (70, 90)]
    rainfall_ranges = [(0, 5), (5, 10), (10, 15), (15, 20), (20, 30)]
    wind_speed_ranges = [(0, 5), (5, 10), (10, 15), (15, 20), (20, 30)]

    # Generate synthetic data for the dataset
    data = {
        "date": [datetime(2000, 1, 1) + timedelta(days=random.randint(0, 7670)) for _ in range(num_records)],
        "observation_time": [time(random.randint(7, 17), random.randint(0, 59), random.randint(0, 59)) for _ in range(num_records)],
        "symptoms": random.choices(symptoms, k=num_records),
        "temperature": [],
        "humidity": [],
        "rainfall": [],
        "wind_speed": [],
        "disease": ["" for _ in range(num_records)]
    }

    # Simulate seasonal variations and daily fluctuations in temperature, humidity, rainfall, and wind speed
    for i in range(num_records):
        date = data["date"][i]
        observation_time = data["observation_time"][i]

        # Simulate seasonal variation (temperature and humidity)
        season = None
        if 3 <= date.month <= 5:  # Spring (March to May)
            season = "Spring"
        elif 6 <= date.month <= 8:  # Summer (June to August)
            season = "Summer"
        elif 9 <= date.month <= 11:  # Autumn/Fall (September to November)
            season = "Autumn"
        else:  # Winter (December to February)
            season = "Winter"

        temperature_range = temperature_ranges_by_season[season]
        humidity_range = humidity_ranges_by_season[season]

        data["temperature"].append(random.uniform(temperature_range[0], temperature_range[1]))
        data["humidity"].append(random.uniform(humidity_range[0], humidity_range[1]))

        # Simulate daily fluctuations (rainfall and wind speed)
        # Higher rainfall during monsoon months (June to September)
        if 6 <= date.month <= 9:
            rainfall_range = rainfall_ranges[3]  # Higher rainfall
        else:
            rainfall_range = rainfall_ranges[date.month % len(rainfall_ranges)]
        data["rainfall"].append(random.uniform(rainfall_range[0], rainfall_range[1]))

        # Higher wind speed during winter (December to February)
        if date.month in [12, 1, 2]:
            wind_speed_range = wind_speed_ranges[3]  # Higher wind speed
        else:
            wind_speed_range = wind_speed_ranges[date.month % len(wind_speed_ranges)]
        data["wind_speed"].append(random.uniform(wind_speed_range[0], wind_speed_range[1]))

    # Assign specific diseases to sets of symptoms and diseases
    for i in range(num_records):
        if data["symptoms"][i] in ["Enlarging root"]:
            data["disease"][i] = "Bakanae"
        elif data["symptoms"][i] in ["Rotten rot"]:
            data["disease"][i] = "Root rot"
        elif data["symptoms"][i] in ["Blackened root"]:
            data["disease"][i] = "Root rot"
        elif data["symptoms"][i] in ["Spotted stem"]:
            data["disease"][i] = random.choice(["Bakanae", 
                                                "Brown Spot", 
                                                "Rice Blast", 
                                                "Stem rot"])
        elif data["symptoms"][i] in ["Rotten stem"]:
            data["disease"][i] = "Stem rot"
        elif data["symptoms"][i] in ["Spotted leaves"]:
            data["disease"][i] = random.choice(["Bacterial Leaf Streak", 
                                                "Brown Spot", 
                                                "Rice Blast", 
                                                "Red Stripe Disease", 
                                                "Bacterial blight", 
                                                "Sheath blight", 
                                                "Leaf scald"])
        elif data["symptoms"][i] in ["Striped leaves"]:
            data["disease"][i] = random.choice(["Bacterial Leaf Streak", 
                                                "Red Stripe Disease", 
                                                "Bacterial blight"])
            
        elif data["symptoms"][i] in ["Withered leaves"]:
            data["disease"][i] = "Rice Tungro"
        elif data["symptoms"][i] in ["Reddened leaves"]:
            data["disease"][i] = "Stem rot"
        elif data["symptoms"][i] in ["Drying leaves"]:
            data["disease"][i] = random.choice(["Bacterial Leaf Streak", 
                                                "Brown Spot", 
                                                "Rice Blast", 
                                                "Red Stripe Disease", 
                                                "Bacterial blight",  
                                                "Leaf scald"])
        elif data["symptoms"][i] in ["Clumped leaves"]:
            data["disease"][i] = "Rice Yellow Mottle"
        elif data["symptoms"][i] in ["Yellowing leaves"]:
            data["disease"][i] = random.choice(["bakanae",
                                                "Bacterial Leaf Streak", 
                                                "Brown Spot",
                                                "Bacterial blight", 
                                                "Rice Tungro", 
                                                "Rice Yellow Mottle",
                                                "Rice Grassy Stunt"])
            
        elif data["symptoms"][i] in ["Spotted panicle"]:
            data["disease"][i] = random.choice(["Brown Spot",
                                                "Rice Blast", 
                                                "Stem rot", 
                                                "Kernel Smut", 
                                                "Bacterial Pinacle Blight"])
        elif data["symptoms"][i] in ["Panicle forms spores"]:
            data["disease"][i] = "False smut"
        elif data["symptoms"][i] in ["Rotten panicle"]:
            data["disease"][i] = random.choice(["Kernel Smut",
                                                "Bacterial Pinacle Blight"])
        elif data["symptoms"][i] in ["Drying panicle"]:
            data["disease"][i] = random.choice(["Kernel Smut",
                                                "Bacterial Pinacle Blight"])
        elif data["symptoms"][i] in ["Shrinking panicles"]:
            data["disease"][i] = random.choice(["Sheath rot",
                                                "False smut"])
        elif data["symptoms"][i] in ["Panicles produce fluid"]:
            data["disease"][i] = "Bacterial Pinacle Blight"
        elif data["symptoms"][i] in ["Panicles falls out"]:
            data["disease"][i] = random.choice(["Stem rot",
                                                "Kernel Smut"])
        elif data["symptoms"][i] in ["Spotted sheath"]:
            data["disease"][i] = random.choice(["Sheath rot",
                                                "Red Stripe Disease",
                                                "Sheath blight"])
        elif data["symptoms"][i] in ["Striped sheath"]:
            data["disease"][i] = "Sheath blight"
        elif data["symptoms"][i] in ["Rotten sheath"]:
            data["disease"][i] = "Sheath rot"
        elif data["symptoms"][i] in ["Drying sheath"]:
            data["disease"][i] = random.choice(["Sheath rot",
                                                "Sheath blight"])
        elif data["symptoms"][i] in ["Decreased yields"]:
            data["disease"][i] = random.choice(["Kernel Smut", 
                                                "Bacterial blight", 
                                                "Bacterial Pinacle Blight", 
                                                "False smut", 
                                                "Leaf scald", 
                                                "Rice Tungro", 
                                                "Rice Grassy Stunt"])
        elif data["symptoms"][i] in ["Plants collapsed easily"]:
            data["disease"][i] = "Root rot"
        elif data["symptoms"][i] in ["Plants grow curved"]:
            data["disease"][i] = random.choice(["Bakanae",
                                                "Rice Blast", 
                                                "Rice Tungro", 
                                                "Rice Yellow Mottle", 
                                                "Rice Grassy Stunt"])
        elif data["symptoms"][i] in ["Plants grow stunted"]:
            data["disease"][i] = random.choice(["Bacterial Leaf Streak", 
                                                "Root rot", 
                                                "Sheath rot", 
                                                "Red Stripe Disease", 
                                                "Sheath blight", 
                                                "Leaf scald",
                                                "Rice Tungro",
                                                "Rice Yellow Mottle"])
        elif data["symptoms"][i] in ["Plants grow tall"]:
            data["disease"][i] = "Bakanae"
        elif data["symptoms"][i] in ["Dwarf"]:
            data["disease"][i] = random.choice(["Rice Yellow Mottle",
                                                "Rice Grassy Stunt"])
            
    # Create the DataFrame from the data dictionary
    df = pd.DataFrame(data)

    # Combine date and observation_time columns to create a single datetime column
    df['datetime'] = pd.to_datetime(df['date'].dt.strftime('%Y-%m-%d') + ' ' + df['observation_time'].astype(str))

    # Sort the dataset by the "datetime" column in ascending order
    df.sort_values(by="datetime", inplace=True)

    # Drop the separate "date" and "observation_time" columns
    df.drop(columns=['date', 'observation_time'], inplace=True)
    
    # Move the "datetime" column to the first position in the DataFrame
    df = df[['datetime'] + df.columns[:-1].tolist()]
    
    return df

# Define temperature and humidity ranges for each season
temperature_ranges_by_season = {
    "Spring": (20, 30),
    "Summer": (25, 35),
    "Autumn": (22, 28),
    "Winter": (18, 25)
}

humidity_ranges_by_season = {
    "Spring": (40, 60),
    "Summer": (50, 70),
    "Autumn": (55, 75),
    "Winter": (60, 80)
}


# Generate a synthetic dataset
dataset = generate_synthetic_dataset(260794)
print(dataset)
